-- %%
%python
df = spark.read.table('01_bronze_catalog.azure_bronze.customers')
display(df)

-- %%
%python

df_new = df.drop("_file", "_line", "_modified", "_fivetran_synced")
display(df_new)

-- %%
ALTER TABLE `01_bronze_catalog`.azure_bronze.customers SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.customers drop column _file, _line, _modified, _fivetran_synced

-- %%
ALTER TABLE `01_bronze_catalog`.azure_bronze.exchange_rates SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.exchange_rates drop column _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoice_line_items SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.invoice_line_items drop column _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoices SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.invoices drop column _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.payments SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.payments drop column _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.products SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.products drop column _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.regions SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
alter table `01_bronze_catalog`.azure_bronze.regions drop column _file, _line, _modified, _fivetran_synced

-- %%
CREATE TABLE `02_silver_catalog`.default.customers AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.customers;

CREATE TABLE `02_silver_catalog`.default.exchange_rates AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.exchange_rates;

CREATE TABLE `02_silver_catalog`.default.invoice_line_items AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.invoice_line_items;

CREATE TABLE `02_silver_catalog`.default.invoices AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.invoices;

CREATE TABLE `02_silver_catalog`.default.payments AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.payments;

CREATE TABLE `02_silver_catalog`.default.products AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.products;

CREATE TABLE `02_silver_catalog`.default.regions AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.regions;
