-- %%
%python
df = spark.read.table('01_bronze_catalog.azure_bronze.customers')
# display(df)

-- %%
%python

df_new = df.drop("_file", "_line", "_modified", "_fivetran_synced")
# display(df_new)

-- %%
ALTER TABLE `01_bronze_catalog`.azure_bronze.customers 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.customers 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.exchange_rates 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.exchange_rates 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoice_line_items 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoice_line_items 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoices 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.invoices 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.payments 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.payments 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.products 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.products 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;
ALTER TABLE `01_bronze_catalog`.azure_bronze.regions 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');
ALTER TABLE `01_bronze_catalog`.azure_bronze.regions 
DROP COLUMN IF EXISTS _file, _line, _modified, _fivetran_synced;

-- %%
CREATE OR REPLACE  TABLE `02_silver_catalog`.transformed_tables.customers AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.customers;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.exchange_rates AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.exchange_rates;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.invoice_line_items AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.invoice_line_items;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.invoices AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.invoices;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.payments AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.payments;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.products AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.products;

CREATE OR REPLACE TABLE `02_silver_catalog`.transformed_tables.regions AS
SELECT * FROM `01_bronze_catalog`.azure_bronze.regions;
