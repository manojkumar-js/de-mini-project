# %%
from pyspark.sql.functions import initcap

products_df = spark.table("02_silver_catalog.default.products")
updated_df = products_df.withColumn("category", initcap("category"))

updated_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("02_silver_catalog.default.products")
